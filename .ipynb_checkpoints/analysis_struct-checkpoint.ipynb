# %%
% matplotlib inline

import pandas as pd, numpy as np
import seaborn as sns
import utils.stats as stats
import utils.viz as viz
import statsmodels.formula.api as smf
import utils.viz as viz
from scipy.stats import shapiro
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

df_r = pd.read_pickle('/home/raid3/oligschlager/workspace/tractdist/data/df_regionwise.pkl')
df_p = pd.read_pickle('/home/raid3/oligschlager/workspace/tractdist/data/df_pairwise.pkl')

# %%
df_r = df_r.rename(columns={'injection distance from nearest primary region': "dist_inj_prim",
                            'incoming': "connectivity_distance"})

# %% [markdown]
# ## outcome variable: DLN ("raw")

# %%
sns.distplot(df_r.connectivity_distance[~df_r.connectivity_distance.isnull()], hist=False)

# %%
viz.plot_inj_yerkes(df_r, 'connectivity_distance', vmin=10, vmax=25)
# Out:
# /home/raid3/oligschlager/anaconda2/envs/distconnect/lib/python2.7/site-packages/nibabel/cifti2/parse_cifti2.py:24: FutureWarning: We no longer carry a copy of the 'six' package in nibabel; Please import the 'six' package directly
#   from ..externals.six import BytesIO
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %% [markdown]
# ## covariate: location (injection's distance from all vertices)

# %%
sns.distplot(df_r.location[~df_r.connectivity_distance.isnull()], hist=False)

# %%
viz.plot_inj_yerkes(df_r, 'location', vmin=25, vmax=60)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %% [markdown]
# ## covariate: region size

# %%
sns.distplot(df_r.region_size[~df_r.connectivity_distance.isnull()], hist=False)
plt.xlim(-200, 3500)
# Out:
# (-200, 3500)

# %%
viz.plot_yerkes(df_r, 'region_size', vmin=0, vmax=800)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %% [markdown]
# # Main analysis

# %%
excl_areas = ['9', '10', '11', '12', '9_46d', '9_46v', '46d', '46v', 'TEpd'] 
# same as in func analysis, but added lateral temporal cortex


fltr = df_r.area.isin(excl_areas)

df_r[['area', 'connectivity_distance', 'dist_inj_prim']][fltr]
# Out:
#      area  connectivity_distance  dist_inj_prim
# 21   TEpd              14.170338      27.890625
# 42  9_46d              17.711961      19.812500
# 44  9_46v              20.402974      26.453125
# 63    46d              11.692618      27.796875
# 64    46v                    NaN            NaN
# 68     11                    NaN            NaN
# 69     12                    NaN            NaN
# 81     10              16.634001      34.531250
# 82      9                    NaN            NaN

# %%
fltr = (df_r.area.isin(excl_areas) | df_r.connectivity_distance.isnull())

# %%
null = smf.ols(formula='connectivity_distance ~ location + region_size', data=df_r[~fltr]).fit()

# %%
model = smf.ols(formula='connectivity_distance ~ location \
                                                 + region_size \
                                                 + dist_inj_prim', data=df_r[~fltr]).fit()
print model.summary()
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     connectivity_distance   R-squared:                       0.716
# Model:                               OLS   Adj. R-squared:                  0.674
# Method:                    Least Squares   F-statistic:                     16.83
# Date:                   Tue, 21 Nov 2017   Prob (F-statistic):           1.08e-05
# Time:                           19:59:42   Log-Likelihood:                -55.341
# No. Observations:                     24   AIC:                             118.7
# Df Residuals:                         20   BIC:                             123.4
# Df Model:                              3
# Covariance Type:               nonrobust
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        30.3358      4.439      6.835      0.000        21.077    39.594
# ...

# %%
df_r['corrected_condist'] = None
df_r['corrected_condist'][~fltr] = null.resid + df_r.connectivity_distance[~fltr].mean()
# Out:
# /nobackup/hunte1/sabine/anaconda2/envs/distconnect/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
sns.set_context('poster')

# %%
#reg_filtr = (~df_area.area.isin(excl_areas_and_prim)) & (df_area.area != '???')

g = sns.jointplot(x="dist_inj_prim", y="corrected_condist", 
                  data=df_r[~fltr], kind='reg', 
                  color="#533cc6", 
                  xlim=(-2,30), ylim=(13,27),
                  stat_func=None)


plt.xticks([0,10,20,30])
plt.yticks([15,25])


g.savefig('/nobackup/hunte1/sabine/tractdist/figures_ms/images/relationship_struct.png', dpi=300)

# %%
df_r[['area', 'corrected_condist']][~fltr & (df_r.corrected_condist > 23)]
# Out:
#    area corrected_condist
# 7    DP           24.0566
# 39   7A           26.7171
# 47    5           24.1628

# %%
viz.plot_inj_yerkes(df_r, 'corrected_condist', 
                    vmin=15, vmax=25, cmap='plasma', surftype='inflated',
                    views=[(180,0), (0,0), (270,90)],
                    f_save='/nobackup/hunte1/sabine/tractdist/figures_ms/images/struct_condist')
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %% [markdown]
# ### with labels

# %%
labels_TEpd = [np.array(df_r[df_r.area=='TEpd'].vertices.iloc[0]),]

# %%
labels_pfc = list()

for area in excl_areas[:-1]:
    
    labels_pfc += list(np.array(df_r[df_r.area==area].vertices.iloc[0]))
    

    
labels_pfc = [np.array(labels_pfc),]

# %%
viz.plot_inj_yerkes(df_r, 'corrected_condist', 
                    vmin=15, vmax=25, cmap='plasma', surftype='inflated',
                    views=[(180,0), (0,0), (270,90)],
                    labels=labels_pfc+labels_TEpd,
                    label_cpal=['magenta', 'grass green'],
                    f_save='/nobackup/hunte1/sabine/tractdist/figures_ms/images/struct_condist')
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %% [markdown]
# ## outcome variable: DLN (corrected)

# %%
df_r['temp'] = np.nan
df_r.temp[~df_r.incoming.isnull()] = null.resid + df_r.incoming.mean()
# Out:
# /nobackup/hunte1/sabine/anaconda2/envs/distconnect/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
sns.distplot(df_r.temp[~df_r.incoming.isnull()], hist=False)

# %%
viz.plot_inj_yerkes(df_r, 'temp', vmin=13, vmax=25)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
